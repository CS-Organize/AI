# %% [markdown]
# https://www.youtube.com/watch?v=cAx5ItHRWkM

# %%
from langchain_ollama import ChatOllama
from IPython.display import display, Markdown

deepseek=ChatOllama(model="deepseek-r1:8b", temperature=0.5)
exaone=ChatOllama(model="exaone3.5", temperature=0.5)

# %%
answer = []
for chunk in deepseek.stream("which is bigger between 9.9 and 9.11?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)

answer_md = ''.join([i for i in answer])
display(Markdown(answer_md))
# Out:
# <think>
# To determine which number is larger between 9.9 and 9.11, I will compare them step by step.
#
# First, I'll align the decimal places to make an accurate comparison easier. I can write 9.9 as 9.90.
#
# Next, I'll compare each digit starting from the left. The units place for both numbers is 9, so they are equal.
#
# Then, I'll look at the tenths place. In 9.90, the tenths digit is 9, while in 9.11, it's 1. Since 9 is greater than 1, 9.90 is larger than 9.11.
#
# Therefore, 9.9 is bigger than 9.11.
# </think>
#
# To determine which number is larger between **9.9** and **9.11**, let's compare them step by step.
#
# ### Step 1: Align the Decimal Places
# First, it's helpful to write both numbers with the same number of decimal places for an accurate comparison.
#
# - **9.9** can be written as **9.90**
# - **9.11** remains **9.11**
#
# ### Step 2: Compare the Numbers Digit by Digit
# Now, compare each digit from left to right.
#
# 1. **Units Place:** Both numbers have a **9** in the units place.
#
# 2. **Tenths Place:**
#    - For **9.90**, the tenths digit is **9**.
#    - For **9.11**, the tenths digit is **1**.
#
#    Since **9 > 1**, **9.90** is greater than **9.11**.
#
# ### Conclusion
# Therefore, **9.9** (or **9.90**) is larger than **9.11**.
#
# \[
# \boxed{9.9 \text{ is bigger than } 9.11}
# \]
# <think>
# To determine which number is larger between 9.9 and 9.11, I will compare them step by step.
#
# First, I'll align the decimal places to make an accurate comparison easier. I can write 9.9 as 9.90.
#
# Next, I'll compare each digit starting from the left. The units place for both numbers is 9, so they are equal.
#
# Then, I'll look at the tenths place. In 9.90, the tenths digit is 9, while in 9.11, it's 1. Since 9 is greater than 1, 9.90 is larger than 9.11.
#
# Therefore, 9.9 is bigger than 9.11.
# </think>
#
# To determine which number is larger between **9.9** and **9.11**, let's compare them step by step.
#
# ### Step 1: Align the Decimal Places
# First, it's helpful to write both numbers with the same number of decimal places for an accurate comparison.
#
# - **9.9** can be written as **9.90**
# - **9.11** remains **9.11**
#
# ### Step 2: Compare the Numbers Digit by Digit
# Now, compare each digit from left to right.
#
# 1. **Units Place:** Both numbers have a **9** in the units place.
#
# 2. **Tenths Place:**
#    - For **9.90**, the tenths digit is **9**.
#    - For **9.11**, the tenths digit is **1**.
#
#    Since **9 > 1**, **9.90** is greater than **9.11**.
#
# ### Conclusion
# Therefore, **9.9** (or **9.90**) is larger than **9.11**.
#
# \[
# \boxed{9.9 \text{ is bigger than } 9.11}
# \]

# %%
answer = []
for chunk in deepseek.stream("9.9와 9.11 중 무엇이 더 큰가요?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)

answer_md = ''.join([i for i in answer])
display(Markdown(answer_md))
# Out:
# <think>
# 首先，我需要比较两个数：9.9和9.11。
#
# 为了方便比较，我可以将它们转换为相同的小数位数。9.9可以写成9.90，而9.11保持不变。
#
# 接下来，逐个数字对比：
#
# 1. **单位位**：两者都是9，所以相等。
#
# 2. **十分位**：9.90的十分位是9，而9.11的十分位是1。因为9大于1，所以9.90大于9.11。
#
# 因此，9.9（即9.90）比9.11更大。
# </think>
#
# **解答：**
#
# 我们需要比较两个数 \( 9.9 \) 和 \( 9.11 \) 的大小。
#
# 1. **统一小数位数：**
#
#    将 \( 9.9 \) 转换为两位小数，得到：
#    \[
#    9.90
#    \]
#
# 2. **逐位比较：**
#
#    - **个位数**：两者都是 \( 9 \)，相等。
#    - **十分位**：\( 9.90 \) 的十分位是 \( 9 \)，而 \( 9.11 \) 的十分位是 \( 1 \)。由于 \( 9 > 1 \)，所以 \( 9.90 > 9.11 \)。
#
# 3. **结论：**
#
#    因此，\( 9.9 \) 大于 \( 9.11 \)。
#
# \[
# \boxed{9.9 > 9.11}
# \]
# <think>
# 首先，我需要比较两个数：9.9和9.11。
#
# 为了方便比较，我可以将它们转换为相同的小数位数。9.9可以写成9.90，而9.11保持不变。
#
# 接下来，逐个数字对比：
#
# 1. **单位位**：两者都是9，所以相等。
#
# 2. **十分位**：9.90的十分位是9，而9.11的十分位是1。因为9大于1，所以9.90大于9.11。
#
# 因此，9.9（即9.90）比9.11更大。
# </think>
#
# **解答：**
#
# 我们需要比较两个数 \( 9.9 \) 和 \( 9.11 \) 的大小。
#
# 1. **统一小数位数：**
#
#    将 \( 9.9 \) 转换为两位小数，得到：
#    \[
#    9.90
#    \]
#
# 2. **逐位比较：**
#
#    - **个位数**：两者都是 \( 9 \)，相等。
#    - **十分位**：\( 9.90 \) 的十分位是 \( 9 \)，而 \( 9.11 \) 的十分位是 \( 1 \)。由于 \( 9 > 1 \)，所以 \( 9.90 > 9.11 \)。
#
# 3. **结论：**
#
#    因此，\( 9.9 \) 大于 \( 9.11 \)。
#
# \[
# \boxed{9.9 > 9.11}
# \]

# %%
answer = []
for chunk in exaone.stream("9.9와 9.11 중 무엇이 더 큰가요?"):
    answer.append(chunk.content)
    print(chunk.content, end="", flush=True)

answer_md = ''.join([i for i in answer])
display(Markdown(answer_md))
# Out:
# 9.11이 9.9보다 더 큽니다. 숫자를 비교할 때는 소수점 뒤의 숫자를 먼저 살펴봅니다. 9.11은 첫 번째 소수점 자리에서 이미 9가 더 크기 때문에 더 큰 수입니다.
# 9.11이 9.9보다 더 큽니다. 숫자를 비교할 때는 소수점 뒤의 숫자를 먼저 살펴봅니다. 9.11은 첫 번째 소수점 자리에서 이미 9가 더 크기 때문에 더 큰 수입니다.

# %%
from langchain_ollama import ChatOllama
from IPython.display import display, Markdown

reasoning_model=ChatOllama(model="deepseek-r1:8b", temperature=0, stop=["</think>"])
generation_model=ChatOllama(model="exaone3.5", temperature=0.7)

# %%
from typing_extensions import TypedDict
from langgraph.graph import START, END, StateGraph
from langchain_core.prompts import ChatPromptTemplate

class State(TypedDict):
    question: str
    thinking: str
    answer: str

answer_prompt = ChatPromptTemplate([
    (
        "system",
        """You are a helpful AI assistant that provides clear and comprehensive answers based on given reasoning.

Your task is to:
- Carefully analyze both the question and the provided reasoning
- Generate a well-structured response that incorporates the insights from the reasoning
- Ensure your answer directly addresses the user's question
- Present the information in a clear and natural way without explicitly mentioning the reasoning process

Guidelines:
- Make your response conversational and engaging
- Focus on being clear and concise while covering all important points
Don't mention that you're using provided reasoning - just incorporate those insights naturally
- Maintain a helpful and professional tone

Remember: Your goal is to provide a natural, informative response that seamlessly incorporates the insights from the reasoning process while directly addressing the user's question."""
    ),
    (
        "human",
        """
Question: {question}
Thinking: {thinking}
"""
    )
])

def think(state: State):
    question = state["question"]
    response = reasoning_model.invoke(question)
    return {"thinking": response.content}

def generate(state: State):
    prompt = answer_prompt.invoke({"question": state["question"], "thinking": state["thinking"]})
    response = generation_model.invoke(prompt)
    return {"answer": response.content}

graph_builder = StateGraph(State).add_sequence([think, generate])
graph_builder.add_edge(START, "think")
graph = graph_builder.compile()

# %%
from IPython.display import Image, Markdown
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
inputs = {"question": "9.9와 9.11 중 무엇이 더 큰가요?"}

async for event in graph.astream_events(inputs, version="v2"):
    # 이벤트 종류와 태그 정보 추출
    kind = event["event"]

    # 채팅 모델 스트림 이벤트 및 최종 노드 태그 필터링
    if kind == "on_chat_model_stream":
        # 이벤트 데이터 추출
        data = event["data"]

        # 출력 메시지
        if data["chunk"].content:
            print(data["chunk"].content, end="", flush=True)
# Out:
# <think>
# 首先，我需要比较两个数：9.9和9.11。
#
# 为了方便比较，我可以将它们转换为相同的小数位数。9.9可以写成9.90，而9.11保持不变。
#
# 接下来，我逐位比较小数部分。第一位小数都是9，所以继续看第二位小数：0和1。由于0小于1，因此9.90小于9.11。
#
# 因此，9.11比9.9更大。
# 9.11이 9.9보다 더 큽니다. 비교를 쉽게 하기 위해 9.9를 9.90으로 생각해 볼 수 있는데, 이렇게 하면 두 숫자의 소수점 아래 자릿수를 쉽게 대조할 수 있습니다. 각 자리수를 보면, 소수 첫째 자리에서는 두 숫자 모두 9와 1로 시작하지만, 둘째 자리에서는 9.90의 경우 0이고 9.11은 1이 됩니다. 0이 1보다 작으므로, 결국 9.11이 더 큰 숫자임을 알 수 있습니다.
